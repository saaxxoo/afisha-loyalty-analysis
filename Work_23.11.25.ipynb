# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Евгений, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши

# %% [markdown]
# ## Этапы выполнения проекта
#
# ### 1. Загрузка данных и их предобработка
#
# ---
#
# **Задача 1.1:** Напишите SQL-запрос, выгружающий в датафрейм pandas необходимые данные.
#
#
#
# Для выгрузки используйте запрос из предыдущего урока и библиотеку SQLAlchemy.
#
# Выгрузка из базы данных SQL должна позволить собрать следующие данные:
#
# - `user_id` — уникальный идентификатор пользователя, совершившего заказ;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ (`mobile` — мобильные устройства, `desktop` — стационарные);
# - `order_id` — уникальный идентификатор заказа;
# - `order_dt` — дата создания заказа (используйте данные `created_dt_msk`);
# - `order_ts` — дата и время создания заказа (используйте данные `created_ts_msk`);
# - `currency_code` — валюта оплаты;
# - `revenue` — выручка от заказа;
# - `tickets_count` — количество купленных билетов;
# - `days_since_prev` — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - `event_id` — уникальный идентификатор мероприятия;
# - `service_name` — название билетного оператора;
# - `event_type_main` — основной тип мероприятия (театральная постановка, концерт и так далее);
# - `region_name` — название региона, в котором прошло мероприятие;
# - `city_name` — название города, в котором прошло мероприятие.
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %% [markdown]
# # Ссылка на репозиторий с проектом
#
# [GitHub Repository](https://github.com/saaxxoo/afisha-loyalty-analysis)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Файлы проекта корректно размещены в репозитории.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Можно было бы добавить файл `README.md` с итоговым выводом по проекту.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В версии, которую ты заливаешь на `GitHub`, не стоит оставлять параметры подключения в явном виде - это может привести к несанкционированному доступу к данным, что чревато их потереей или изменением. Лучшее решение - локально создать `.env` файл, из которого с помощью `os` эти параметры подключения передаются в код. А файл `.gitignore` поможет не отслеживать этот файл для репозитория.
#
# Файл `.env` может выглядеть так:
#
# ```python
# DB_NAME="..."
# DB_HOST="..."
# DB_PORT="..."
# DB_USER="..."
# DB_PASSWORD="..."
# ```
#
# В самом проекте мы можем обращаться к сохраненным параметрам с помощью библиотеки `dotenv`, чтобы загрузить переменные окружения, и `os`, чтобы обратиться к ним:
#
# ```python
# import os
# import dotenv
#
# load_dotenv() # автоматически ищет .env в текущей директории
#
# connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
#     os.getenv('DB_USER'),
#     os.getenv('DB_PASSWORD'),
#     os.getenv('DB_HOST'),
#     os.getenv('DB_PORT'),
#     os.getenv('DB_NAME'),
# )
# ```
#
# Параметры подключения также стоит удалить из описания проекта:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> К этому замечанию нужно вернуться.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут всё ещё актуально - подскажи, есть какие-то сложности?

# %%
# Используйте ячейки типа Code для вашего кода,
# а ячейки типа Markdown для комментариев и выводов

# %%
# При необходимости добавляйте новые ячейки для кода или текста

# %%
import pandas as pd
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import seaborn as sns
import phik
from phik.report import plot_correlation_matrix

# %%
# Загружаем переменные из файла .env
load_dotenv()

# Параметры подключения берем из окружения
db_config = {
    'user': os.getenv('DB_USER'),
    'pwd':  os.getenv('DB_PASSWORD'),
    'host': os.getenv('DB_HOST'),
    'port': os.getenv('DB_PORT'),
    'db':   os.getenv('DB_NAME')
}

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    db_config['user'], db_config['pwd'], db_config['host'], db_config['port'], db_config['db']
)

engine = create_engine(connection_string)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали, коннектор сделали - отлично!

# %%
# Скорректированный SQL-запрос с учетом реальной структуры таблиц
query = '''
SELECT
    p.user_id,
    p.device_type_canonical,
    p.order_id,
    p.created_dt_msk AS order_dt,
    p.created_ts_msk AS order_ts,
    p.currency_code,
    p.revenue,
    p.tickets_count,
    EXTRACT(EPOCH FROM (p.created_ts_msk - LAG(p.created_ts_msk) OVER (PARTITION BY p.user_id ORDER BY p.created_ts_msk))) / 86400 AS days_since_prev,
    p.event_id,
    p.service_name,
    e.event_type_main,
    c.city_name,
    r.region_name
FROM afisha.purchases AS p
LEFT JOIN afisha.events AS e ON p.event_id = e.event_id
LEFT JOIN afisha.city AS c ON e.city_id = c.city_id
LEFT JOIN afisha.regions AS r ON c.region_id = r.region_id
'''

# Загружаем данные
df = pd.read_sql_query(query, con=engine)

# Проверяем типы данных и наличие новых колонок
display(df.info())
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292034 entries, 0 to 292033
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                292034 non-null  object
#  1   device_type_canonical  292034 non-null  object
#  2   order_id               292034 non-null  int64
#  3   order_dt               292034 non-null  datetime64[ns]
#  4   order_ts               292034 non-null  datetime64[ns]
#  5   currency_code          292034 non-null  object
#  6   revenue                292034 non-null  float64
#  7   tickets_count          292034 non-null  int64
#  8   days_since_prev        270034 non-null  float64
#  9   event_id               292034 non-null  int64
#  10  service_name           292034 non-null  object
#  11  event_type_main        292034 non-null  object
#  12  city_name              292034 non-null  object
#  13  region_name            292034 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Данные выгружены из SQL запроса.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Метод `.print()` не очень подходит для работы с таблицами типа `pd.DataFrame`, так как выводит их на экран просто как отформатированный текст. Для отображения небольших таблиц можно воспользоваться методом `.head()`, для таблиц побольше - модулем `display`.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# **Задача 1.2:** Изучите общую информацию о выгруженных данных. Оцените корректность выгрузки и объём полученных данных.
#
# Предположите, какие шаги необходимо сделать на стадии предобработки данных — например, скорректировать типы данных.
#
# Зафиксируйте основную информацию о данных в кратком промежуточном выводе.
#
# ---

# %%
# Общая информация о типах и пропусках
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292034 entries, 0 to 292033
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                292034 non-null  object
#  1   device_type_canonical  292034 non-null  object
#  2   order_id               292034 non-null  int64
#  3   order_dt               292034 non-null  datetime64[ns]
#  4   order_ts               292034 non-null  datetime64[ns]
#  5   currency_code          292034 non-null  object
#  6   revenue                292034 non-null  float64
#  7   tickets_count          292034 non-null  int64
#  8   days_since_prev        270034 non-null  float64
#  9   event_id               292034 non-null  int64
#  10  service_name           292034 non-null  object
#  11  event_type_main        292034 non-null  object
#  12  city_name              292034 non-null  object
#  13  region_name            292034 non-null  object
# ...

# %%
# Первые 5 строк для общего понимания структуры и проверки данных
display(df.head())
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4        74.805301
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3        83.119757
#
#    event_id        service_name event_type_main    city_name  \
# 0    169230        Край билетов           театр   Глиногорск
# ...

# %%
# Статистика по числовым столбцам
display(df.describe())
# Out:
#            order_id                       order_dt  \
# count  2.920340e+05                         292034
# mean   4.326435e+06  2024-09-01 21:06:45.100776448
# min    1.000000e+00            2024-06-01 00:00:00
# 25%    2.162567e+06            2024-07-30 00:00:00
# 50%    4.327134e+06            2024-09-12 00:00:00
# 75%    6.489179e+06            2024-10-09 00:00:00
# max    8.653108e+06            2024-10-31 00:00:00
# std    2.498049e+06                            NaN
#
#                             order_ts        revenue  tickets_count  \
# count                         292034  292034.000000  292034.000000
# mean   2024-09-02 12:01:25.812875008     624.833773       2.754508
# min              2024-06-01 00:00:42     -90.760000       1.000000
# 25%       2024-07-30 11:48:37.500000     116.790000       2.000000
# 50%       2024-09-12 13:04:46.500000     355.340000       3.000000
# 75%    2024-10-09 15:36:04.249999872     809.460000       4.000000
# ...

# %%
# Статистика по категориальным столбцам
display(df.describe(include=['object', 'category']))
# Out:
#                 user_id device_type_canonical currency_code  \
# count            292034                292034        292034
# unique            22000                     5             2
# top     0beb8fc0c0a9ce1                mobile           rub
# freq              10313                232679        286961
#
#               service_name event_type_main   city_name         region_name
# count               292034          292034      292034              292034
# unique                  36               8         352                  81
# top     Билеты без проблем        концерты  Глиногорск  Каменевский регион
# freq                 63932          115634       90087               91701

# %%
# Проверка наличия пропусков по всем столбцам (в процентах)
missing_pct = df.isnull().mean() * 100
print('Процент пропусков по столбцам:\n', missing_pct)
# Out:
# Процент пропусков по столбцам:
#  user_id                  0.000000
# device_type_canonical    0.000000
# order_id                 0.000000
# order_dt                 0.000000
# order_ts                 0.000000
# currency_code            0.000000
# revenue                  0.000000
# tickets_count            0.000000
# days_since_prev          7.533369
# event_id                 0.000000
# service_name             0.000000
# event_type_main          0.000000
# city_name                0.000000
# region_name              0.000000
# dtype: float64

# %% [markdown]
# **Общая информация:**
# * В датасете 292 034 записи.
# * Явных дубликатов нет (предварительная оценка)
#
# **Проблемы, выявленные при обзоре:**
# 1.  **Типы данных:**
#     * Столбцы `created_dt_msk` и `created_ts_msk` имеют тип `object`, их необходимо привести к `datetime`.
#     * Столбцы `device_type_canonical`, `currency_code`, `service_name` имеют тип `object`, для экономии памяти и удобства их можно привести к `category`.
# 2.  **Названия столбцов:**
#     * Требуется переименовать `created_dt_msk` -> `order_dt` и `created_ts_msk` -> `order_ts` для удобства.
# 3.  **Пропуски:**
#     * Обнаружены пропуски в столбце `days_since_prev` (~7.5%). Это ожидаемо для пользователей, совершивших первую покупку (у них нет "предыдущего" заказа).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выполнен первичный анализ данных.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> На данном этапе никакая обработка не требуется - тут мы просто знакомимся с данными, а уже обработку делаем в следующем шаге. Тут нужно только наметить шаги по обработке, которая будет выполнена далее.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# ###  2. Предобработка данных
#
# Выполните все стандартные действия по предобработке данных:
#
# ---
#
# **Задача 2.1:** Данные о выручке сервиса представлены в российских рублях и казахстанских тенге. Приведите выручку к единой валюте — российскому рублю.
#
# Для этого используйте датасет с информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год — `final_tickets_tenge_df.csv`. Его можно загрузить по пути `https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')`
#
# Значения в рублях представлено для 100 тенге.
#
# Результаты преобразования сохраните в новый столбец `revenue_rub`.
#
# ---

# %%
# Приведение колонок order_dt и order_ts к datetime
df.rename(columns={'created_dt_msk': 'order_dt', 'created_ts_msk': 'order_ts'}, inplace=True)
df['order_dt'] = pd.to_datetime(df['order_dt'])
df['order_ts'] = pd.to_datetime(df['order_ts'])
display(df.head())
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4        74.805301
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3        83.119757
#
#    event_id        service_name event_type_main    city_name  \
# 0    169230        Край билетов           театр   Глиногорск
# ...

# %%
# Проверка и удаление дубликатов (опционально)
duplicates_count = df.duplicated().sum()
print('Количество дубликатов:', duplicates_count)
# Out:
# Количество дубликатов: 0

# %%
# Преобразование категориальных столбцов в тип category для оптимизации
categorical_cols = ['device_type_canonical', 'currency_code', 'service_name']
for col in categorical_cols:
    df[col] = df[col].astype('category')
    display(df.head())
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4        74.805301
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3        83.119757
#
#    event_id        service_name event_type_main    city_name  \
# 0    169230        Край билетов           театр   Глиногорск
# ...

# %%
# Загрузка датасета с курсами
url = 'https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv'
tenge_rate_df = pd.read_csv(url)

# Приведение столбцов с датами к datetime
tenge_rate_df['data'] = pd.to_datetime(tenge_rate_df['data'])

# Меняем тенге на рубли
tenge_rate_df['rate_per_tenge'] = tenge_rate_df['curs'] / tenge_rate_df['nominal']
rate_map = tenge_rate_df.set_index('data')['rate_per_tenge']

# Подготовка дат в основном датафрейме
df['order_date_norm'] = df['order_dt'].dt.normalize()

# Векторизированное сопоставление курсов
df['rate'] = df['order_date_norm'].map(rate_map)

# Расчет выручки с использованием маски
df['revenue_rub'] = df['revenue']

mask_kzt = df['currency_code'] == 'kzt'

df.loc[mask_kzt, 'revenue_rub'] = df['revenue'] * df['rate'].fillna(1)

df.drop(columns=['order_date_norm', 'rate'], inplace=True)

print(df[['order_dt', 'revenue', 'currency_code', 'revenue_rub']].head())
print("\nПроверка конвертации для тенге (примеры):")
display(df[df['currency_code'] == 'kzt'][['order_dt', 'revenue', 'currency_code', 'revenue_rub']].head())
# Out:
#     order_dt  revenue currency_code  revenue_rub
# 0 2024-08-20  1521.94           rub      1521.94
# 1 2024-07-23   289.45           rub       289.45
# 2 2024-10-06  1258.57           rub      1258.57
# 3 2024-07-13     8.49           rub         8.49
# 4 2024-10-04  1390.41           rub      1390.41
#
# Проверка конвертации для тенге (примеры):
#       order_dt   revenue currency_code  revenue_rub
# 73  2024-09-17    518.10           kzt    98.503762
# 92  2024-09-02    347.18           kzt    65.731589
# 99  2024-09-09    328.77           kzt    61.148261
# 289 2024-06-11  22021.55           kzt  4380.702898
# 472 2024-06-04   3698.83           kzt   739.148295

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выручка приведена к единой валюте.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Решение с `.apply` неэффективное, так как оно применяет функцию к каждой строке таблицы поочерёдно - это может быть затратно на больших таблицах. Лучше использовать маски:
#
#
# ```py# Создаем Series (словарь) из курсов: 'data' -> 'curs'
# # Это нужно сделать один раз, а не на каждой строке.
# rate_map = exchange_rates.set_index('data')['curs']
#
# # Используем .map() для "подтягивания" курса в df по дате 'order_dt'
# # Это C-оптимизированная операция, во много раз быстрее apply
# df['rate'] = df['order_dt'].map(rate_map)
#
# # Инициализируем новую колонку значением по умолчанию
# df['revenue_rub'] = df['revenue']
#
# # Создаем маску (условие) для строк, которые нужно конвертировать
# mask = df['currency_code'] == 'kzt'
#
# # Выполняем векторизированную операцию ТОЛЬКО для нужных строк
# df.loc[mask, 'revenue_rub'] = df['revenue'] * df['rate'] / 100
# ```

# %% [markdown]
# ---
#
# **Задача 2.2:**
#
# - Проверьте данные на пропущенные значения. Если выгрузка из SQL была успешной, то пропуски должны быть только в столбце `days_since_prev`.
# - Преобразуйте типы данных в некоторых столбцах, если это необходимо. Обратите внимание на данные с датой и временем, а также на числовые данные, размерность которых можно сократить.
# - Изучите значения в ключевых столбцах. Обработайте ошибки, если обнаружите их.
#     - Проверьте, какие категории указаны в столбцах с номинальными данными. Есть ли среди категорий такие, что обозначают пропуски в данных или отсутствие информации? Проведите нормализацию данных, если это необходимо.
#     - Проверьте распределение численных данных и наличие в них выбросов. Для этого используйте статистические показатели, гистограммы распределения значений или диаграммы размаха.
#
#         Важные показатели в рамках поставленной задачи — это выручка с заказа (`revenue_rub`) и количество билетов в заказе (`tickets_count`), поэтому в первую очередь проверьте данные в этих столбцах.
#
#         Если обнаружите выбросы в поле `revenue_rub`, то отфильтруйте значения по 99 перцентилю.
#
# После предобработки проверьте, были ли отфильтрованы данные. Если были, то оцените, в каком объёме. Сформулируйте промежуточный вывод, зафиксировав основные действия и описания новых столбцов.
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Все библиотеки стоит импортировать в начале проекта - таким образом получатель твоего отчёта сможет узнать о проблемах с его окружением сразу перед работой с проектом, а не посреди или в конце проекта. Тут и далее по проекту.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# График для выручки
sns.boxplot(x=df['revenue_rub'], ax=axes[0], color='skyblue')
axes[0].set_title('Ящик с усами: Выручка (revenue_rub)')
axes[0].set_xlabel('Рубли')

# График для билетов
sns.boxplot(x=df['tickets_count'], ax=axes[1], color='lightgreen')
axes[1].set_title('Ящик с усами: Количество билетов (tickets_count)')
axes[1].set_xlabel('Штуки')

plt.show()

# %% [markdown]
# * На диаграммах размаха по `revenue_rub` наблюдается большое количество выбросов — единичных заказов с аномально высокой стоимостью. Это смещало средние показатели и могло исказить дальнейший анализ.
# * По столбцу `tickets_count` распределение более компактное, основная масса заказов содержит от 1 до 5 билетов.

# %%
print("Статистика до фильтрации:")
print(df[['revenue_rub', 'tickets_count']].describe())

p99_revenue = df['revenue_rub'].quantile(0.99)
print(f"\n99-й перцентиль по revenue_rub: {p99_revenue:.2f}")

original_len = len(df)
df_filtered = df[df['revenue_rub'] <= p99_revenue].copy()
new_len = len(df_filtered)

deleted_count = original_len - new_len
deleted_share = (deleted_count / original_len) * 100

print(f"Удалено записей: {deleted_count}")
print(f"Доля удаленных данных: {deleted_share:.2f}%")

print("\nСтатистика после фильтрации:")
print(df_filtered[['revenue_rub', 'tickets_count']].describe())

df = df_filtered
# Out:
# Статистика до фильтрации:
#          revenue_rub  tickets_count
# count  292034.000000  292034.000000
# mean      555.106238       2.754508
# std       874.381090       1.170305
# min       -90.760000       1.000000
# 25%       113.480000       2.000000
# 50%       350.330000       3.000000
# 75%       802.050000       4.000000
# max     81174.540000      57.000000
#
# 99-й перцентиль по revenue_rub: 2628.42
# Удалено записей: 2840
# Доля удаленных данных: 0.97%
#
# Статистика после фильтрации:
#          revenue_rub  tickets_count
# count  289194.000000  289194.000000
# mean      517.581592       2.740669
# std       511.902358       1.162724
# min       -90.760000       1.000000
# 25%       111.492500       2.000000
# 50%       343.500000       3.000000
# 75%       788.490000       3.000000
# max      2628.421739      57.000000

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Численные признаки изучены, удалены выбросы.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Для анализа выбросов дополнительно стоит визуализировать ящик с усами. По результатам обработки численных признаков стоит сделать вывод.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# ### 3. Создание профиля пользователя
#
# В будущем отдел маркетинга планирует создать модель для прогнозирования возврата пользователей. Поэтому сейчас они просят вас построить агрегированные признаки, описывающие поведение и профиль каждого пользователя.
#
# ---
#
# **Задача 3.1.** Постройте профиль пользователя — для каждого пользователя найдите:
#
# - дату первого и последнего заказа;
# - устройство, с которого был сделан первый заказ;
# - регион, в котором был сделан первый заказ;
# - билетного партнёра, к которому обращались при первом заказе;
# - жанр первого посещённого мероприятия (используйте поле `event_type_main`);
# - общее количество заказов;
# - средняя выручка с одного заказа в рублях;
# - среднее количество билетов в заказе;
# - среднее время между заказами.
#
# После этого добавьте два бинарных признака:
#
# - `is_two` — совершил ли пользователь 2 и более заказа;
# - `is_five` — совершил ли пользователь 5 и более заказов.
#
# **Рекомендация:** перед тем как строить профиль, отсортируйте данные по времени совершения заказа.
#
# ---

# %%
df.sort_values(by=['user_id', 'order_ts'], inplace=True)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Разница между событиями уже посчитана в `days_since_prev` - повторно пересчитывать её не нужно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Формируем словарь агрегации
agg_config = {
    'order_ts': ['first', 'last'],        # Даты первого и последнего заказа
    'device_type_canonical': 'first',     # Устройство первого заказа
    'region_name': 'first',               # Регион первого заказа
    'service_name': 'first',              # Билетный партнер первого заказа
    'event_type_main': 'first',           # Жанр первого заказа
    'order_id': 'count',                  # Общее количество заказов
    'revenue_rub': 'mean',                # Средняя выручка
    'tickets_count': 'mean',              # Среднее количество билетов
    'days_since_prev': 'mean'                   # Средний интервал между заказами
}

profiles = df.groupby('user_id').agg(agg_config)
profiles.columns = ['_'.join(col).strip() for col in profiles.columns.values]

# Переименовываем столбцы
rename_map = {
    'order_ts_first': 'first_order_dt',
    'order_ts_last': 'last_order_dt',
    'device_type_canonical_first': 'first_device',
    'region_name_first': 'first_region',
    'service_name_first': 'first_partner',
    'event_type_main_first': 'first_genre',
    'order_id_count': 'total_orders',
    'revenue_rub_mean': 'avg_revenue',
    'tickets_count_mean': 'avg_tickets',
    'days_diff_mean': 'avg_inter_order_time'
}
profiles.rename(columns=rename_map, inplace=True)

# Добавляем бинарные признаки лояльности
profiles['is_two'] = (profiles['total_orders'] >= 2).astype(int)
profiles['is_five'] = (profiles['total_orders'] >= 5).astype(int)

# Вывод результатов
display(profiles.head())
display(profiles.info())
# Out:
#                      first_order_dt       last_order_dt first_device  \
# user_id
# 0002849b70a3ce2 2024-08-20 16:08:03 2024-08-20 16:08:03       mobile
# 0005ca5e93f2cf4 2024-07-23 18:36:24 2024-10-06 13:56:02       mobile
# 000898990054619 2024-07-13 19:40:48 2024-10-23 15:12:00       mobile
# 00096d1f542ab2b 2024-08-15 16:48:48 2024-08-15 16:48:48      desktop
# 000a55a418c128c 2024-09-29 19:39:12 2024-10-15 10:29:04       mobile
#
#                          first_region  first_partner first_genre  \
# user_id
# 0002849b70a3ce2    Каменевский регион   Край билетов       театр
# 0005ca5e93f2cf4    Каменевский регион      Мой билет    выставки
# 000898990054619  Североярская область    Лови билет!      другое
# 00096d1f542ab2b    Каменевский регион   Край билетов       театр
# 000a55a418c128c      Поленовский край  Лучшие билеты       театр
#
#                  total_orders  avg_revenue  avg_tickets  days_since_prev_mean  \
# user_id
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Профиль пользователя создан, добавлены бинарные признаки.

# %% [markdown]
# ---
#
# **Задача 3.2.** Прежде чем проводить исследовательский анализ данных и делать выводы, важно понять, с какими данными вы работаете: насколько они репрезентативны и нет ли в них аномалий.
#
# Используя данные о профилях пользователей, рассчитайте:
#
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.
#
# Также изучите статистические показатели:
#
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками.
#
# По результатам оцените данные: достаточно ли их по объёму, есть ли аномальные значения в данных о количестве заказов и среднем количестве билетов?
#
# Если вы найдёте аномальные значения, опишите их и примите обоснованное решение о том, как с ними поступить:
#
# - Оставить и учитывать их при анализе?
# - Отфильтровать данные по какому-то значению, например, по 95-му или 99-му перцентилю?
#
# Если вы проведёте фильтрацию, то вычислите объём отфильтрованных данных и выведите статистические показатели по обновлённому датасету.

# %%
if 'days_since_prev_mean' in profiles.columns:
    profiles.rename(columns={'days_since_prev_mean': 'avg_inter_order_time'}, inplace=True)

print(profiles.columns)
# Out:
# Index(['first_order_dt', 'last_order_dt', 'first_device', 'first_region',
#        'first_partner', 'first_genre', 'total_orders', 'avg_revenue',
#        'avg_tickets', 'avg_inter_order_time', 'is_two', 'is_five'],
#       dtype='object')

# %%
total_users = len(profiles)
avg_revenue_per_order_users = profiles['avg_revenue'].mean()
share_is_two = profiles['is_two'].mean() * 100
share_is_five = profiles['is_five'].mean() * 100

print(f"Общее число пользователей: {total_users}")
print(f"Средняя выручка с одного заказа (по профилям): {avg_revenue_per_order_users:.2f} руб.")
print(f"Доля пользователей с 2+ заказами: {share_is_two:.2f}%")
print(f"Доля пользователей с 5+ заказами: {share_is_five:.2f}%")
# Out:
# Общее число пользователей: 21920
# Средняя выручка с одного заказа (по профилям): 543.46 руб.
# Доля пользователей с 2+ заказами: 61.77%
# Доля пользователей с 5+ заказами: 29.01%

# %%
print("Статистика до фильтрации")
print("\n1. По общему числу заказов (total_orders):")
print(profiles['total_orders'].describe())

print("\n2. По среднему числу билетов в заказе (avg_tickets):")
print(profiles['avg_tickets'].describe())

print("\n3. По среднему количеству дней между покупками (avg_inter_order_time):")
print(profiles['avg_inter_order_time'].describe())
# Out:
# Статистика до фильтрации
#
# 1. По общему числу заказов (total_orders):
# count    21920.000000
# mean        13.193157
# std        122.132781
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max      10243.000000
# Name: total_orders, dtype: float64
#
# 2. По среднему числу билетов в заказе (avg_tickets):
# count    21920.000000
# mean         2.742845
# std          0.912611
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.072321
# max         11.000000
# Name: avg_tickets, dtype: float64
#
# 3. По среднему количеству дней между покупками (avg_inter_order_time):
# count    13568.000000
# mean        15.854858
# std         22.319813
# min          0.000012
# 25%          1.030833
# 50%          8.072555
# 75%         20.385313
# max        148.227755
# Name: avg_inter_order_time, dtype: float64

# %%
# Поиск аномалий и принятие решения
# Проверяем аномалии в количестве билетов (как наиболее критичные для анализа B2C)
p99_tickets = profiles['avg_tickets'].quantile(0.99)
max_tickets = profiles['avg_tickets'].max()

print(f"99-й перцентиль по билетам: {p99_tickets:.2f}")
print(f"Максимальное значение по билетам: {max_tickets:.2f}")
# Out:
# 99-й перцентиль по билетам: 5.00
# Максимальное значение по билетам: 11.00

# %%
# Фильтрация
profiles_clean = profiles[profiles['avg_tickets'] <= p99_tickets].copy()

deleted_count = len(profiles) - len(profiles_clean)
deleted_share = (deleted_count / len(profiles)) * 100

print(f"Удалено пользователей: {deleted_count}")
print(f"Доля удаленных данных: {deleted_share:.2f}%")

profiles = profiles_clean

# Вывод статистических показателей по обновленному датасету
print("\nСтатистика после фильтрации")
print("\n1. По общему числу заказов (total_orders):")
print(profiles['total_orders'].describe())

print("\n2. По среднему числу билетов в заказе (avg_tickets):")
print(profiles['avg_tickets'].describe())

print("\n3. По среднему количеству дней между покупками (avg_inter_order_time):")
print(profiles['avg_inter_order_time'].describe())
# Out:
# Удалено пользователей: 194
# Доля удаленных данных: 0.89%
#
# Статистика после фильтрации
#
# 1. По общему числу заказов (total_orders):
# count    21726.000000
# mean        13.294900
# std        122.671993
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max      10243.000000
# Name: total_orders, dtype: float64
#
# 2. По среднему числу билетов в заказе (avg_tickets):
# count    21726.000000
# mean         2.713767
# std          0.860383
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.000000
# max          5.000000
# Name: avg_tickets, dtype: float64
#
# 3. По среднему количеству дней между покупками (avg_inter_order_time):
# count    13503.000000
# mean        15.899240
# std         22.332129
# min          0.000012
# 25%          1.080808
# 50%          8.116309
# 75%         20.473413
# max        148.227755
# Name: avg_inter_order_time, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Статистики по профилю пользователя изучены, удалены выбросы.

# %% [markdown]
# ---
#
# ### 4. Исследовательский анализ данных
#
# Следующий этап — исследование признаков, влияющих на возврат пользователей, то есть на совершение повторного заказа. Для этого используйте профили пользователей.

# %% [markdown]
# #### 4.1. Исследование признаков первого заказа и их связи с возвращением на платформу
#
# Исследуйте признаки, описывающие первый заказ пользователя, и выясните, влияют ли они на вероятность возвращения пользователя.
#
# ---
#
# **Задача 4.1.1.** Изучите распределение пользователей по признакам.
#
# - Сгруппируйте пользователей:
#     - по типу их первого мероприятия;
#     - по типу устройства, с которого совершена первая покупка;
#     - по региону проведения мероприятия из первого заказа;
#     - по билетному оператору, продавшему билеты на первый заказ.
# - Подсчитайте общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака. Сегмент — это группа пользователей, объединённых определённым признаком, то есть объединённые принадлежностью к категории. Например, все клиенты, сделавшие первый заказ с мобильного телефона, — это сегмент.
# - Ответьте на вопрос: равномерно ли распределены пользователи по сегментам или есть выраженные «точки входа» — сегменты с наибольшим числом пользователей?
#
# ---

# %%
# Список признаков для анализа (из профиля пользователя)
features = ['first_genre', 'first_device', 'first_region', 'first_partner']
feature_names = {
    'first_genre': 'Жанр первого мероприятия',
    'first_device': 'Устройство',
    'first_region': 'Регион',
    'first_partner': 'Билетный партнер'
}

# Средняя доля возвратов по всей выборке
avg_retention = profiles['is_two'].mean()

for feature in features:
    # Группировка и расчет метрик (Объединяем задачи 4.1.1 и 4.1.2)
    stats = profiles.groupby(feature).agg({
        'total_orders': 'count',    # Количество пользователей (размер сегмента)
        'is_two': 'mean'            # Доля вернувшихся (retention rate)
    }).reset_index()

    # Переименование для удобства
    stats.rename(columns={'total_orders': 'user_count', 'is_two': 'retention_rate'}, inplace=True)

    # Считаем долю сегмента от всех пользователей (для ответа на вопрос о "точках входа")
    stats['share_of_users_pct'] = (stats['user_count'] / len(profiles)) * 100

    # Сортируем по количеству пользователей, чтобы видеть самые популярные сегменты первыми
    stats = stats.sort_values(by='user_count', ascending=False)

    # Вывод таблицы (Топ-10 строк для наглядности)
    print(f"Анализ по признаку: {feature_names[feature]}")
    print(stats.head(10).to_string(index=False))

    # Визуализация (Задача 4.1.2)
    # Берем топ-10 сегментов по популярности для графика, чтобы он не был перегружен
    plot_data = stats.head(10).copy()

    plt.figure(figsize=(10, 5))

    # Строим столбчатую диаграмму доли возвратов
    # Зеленым выделим те сегменты, где возврат выше среднего, серым — где ниже
    colors = ['green' if x > avg_retention else 'gray' for x in plot_data['retention_rate']]

    plt.bar(plot_data[feature].astype(str), plot_data['retention_rate'], color=colors, alpha=0.7)

    # Линия среднего уровня возврата
    plt.axhline(y=avg_retention, color='red', linestyle='--', label=f'Среднее ({avg_retention:.2f})')

    plt.title(f'Доля возврата (2+ заказа) по: {feature_names[feature]} (Топ-10)')
    plt.ylabel('Доля возврата')
    plt.xlabel(feature_names[feature])
    plt.xticks(rotation=45, ha='right')
    plt.legend()
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.show()
# Out:
# Анализ по признаку: Жанр первого мероприятия
# first_genre  user_count  retention_rate  share_of_users_pct
#    концерты        9610        0.623101           44.232717
#      другое        5415        0.604801           24.924054
#       театр        4275        0.642105           19.676885
#     стендап        1102        0.617967            5.072264
#       спорт         789        0.564005            3.631593
#    выставки         415        0.643373            1.910154
#        ёлки          93        0.559140            0.428059
#       фильм          27        0.814815            0.124275
# Анализ по признаку: Устройство
# first_device  user_count  retention_rate  share_of_users_pct
#       mobile       17930        0.615561           82.527847
#      desktop        3699        0.645039           17.025684
#       tablet          97        0.536082            0.446470
#        other           0             NaN            0.000000
# ...

# %% [markdown]
# ### Вывод по распределению пользователей
#
# Пользователи распределены по сегментам неравномерно, в каждой категории есть выраженные «точки входа»:
#
# * **Устройства:** Абсолютное доминирование мобильных устройств — **82.5%** пользователей совершают первый заказ со смартфонов. Desktop составляет лишь 17%.
# * **Жанры:** Самая популярная точка входа — **«Концерты»** (44.2% пользователей). На втором месте категория «Другое» (25%), на третьем — «Театр» (19.7%).
# * **Регионы:** Явный лидер — **Каменевский регион**, откуда приходит **32.8%** всей аудитории. На втором месте Североярская область (17.3%). Остальные регионы занимают менее 6% каждый.
# * **Билетные партнеры:**
#     * Лидером среди операторов является **«Билеты без проблем»**, через которого приходят **23.8%** пользователей.
#     * Также значимые доли занимают «Мой билет» (13.7%), «Лови билет!» (13.0%) и «Билеты в руки» (11.9%).
#     * Рынок партнеров более фрагментирован, чем рынок устройств или регионов, но топ-4 игрока охватывают более 60% аудитории.
#     *

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно рассчитал доли пользователей в каждом сегменте. Вывод о том, что распределение неравномерное, полностью подтверждается данными таблиц.
#
# Ключевые «точки входа» определены правильно: ты точно подметил доминирование мобильных устройств, популярность концертов как первого события и явное лидерство Каменевского региона.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В итоговом списке выводов ты упустил один из критериев задания - билетных партнеров. Таблицу по ним ты построил, и там есть явный лидер (Билеты без проблем с долей почти 24%), но в текстовом заключении этот момент никак не отражен. Стоит добавить этот пункт, чтобы полностью закрыть требования задачи по всем четырем признакам.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# **Задача 4.1.2.** Проанализируйте возвраты пользователей:
#
# - Для каждого сегмента вычислите долю пользователей, совершивших два и более заказа.
# - Визуализируйте результат подходящим графиком. Если сегментов слишком много, то поместите на график только 10 сегментов с наибольшим количеством пользователей. Такое возможно с сегментами по региону и по билетному оператору.
# - Ответьте на вопросы:
#     - Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?
#     - Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?
#
# При интерпретации результатов учитывайте размер сегментов: если в сегменте мало пользователей (например, десятки), то доли могут быть нестабильными и недостоверными, то есть показывать широкую вариацию значений.
#
# ---

# %% [markdown]
# Средний уровень возврата по выборке составляет 61.8%
# - Самая успешная точка входа — Театр (64.2%) и Выставки (64.3%). Пользователи, начавшие с этих жанров, возвращаются чаще, чем те, кто начал с концертов (62.3%)
# - Пользователи Desktop более лояльны (64.5%), чем мобильные пользователи (61.6%)
# - Высокая лояльность в Шанырском регионе (67.4%) и Светополянском округе (66.4%), хотя они и небольшие по объему. Крупные регионы (Каменевский, Североярская) также показывают результаты выше среднего.
#
# - Низкий возврат показывают пользователи, пришедшие через жанр Спорт (56.4%) и Елки (55.9%)
# - Озернинский край и Малиновоярский округ имеют показатели возврата значительно ниже среднего
# - Среди билетных партнёров одними из самых лояльных являются «Край билетов» и «Дом культуры» — у них показатели возврата выше среднего.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты отлично справился с интерпретацией данных. Цифры в выводах точно соответствуют табличным значениям (с учетом перевода долей в проценты).
#
# Особенно хорошо, что ты учел рекомендацию про размер выборки. Например, ты не стал указывать категорию "фильм" как лидера, хотя там самый высокий показатель возврата (0.81), потому что там всего 27 пользователей. Также ты грамотно отметил, что Шанырский регион и Светополянский округ показывают высокую лояльность, но имеют малый объем. Это говорит о качественном подходе к анализу.
#
# Сравнение жанров и платформ проведено верно: ты правильно выделил театр и выставки как более успешные точки входа по сравнению с концертами, а также подтвердил большую лояльность пользователей десктопа.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Пропущен анализ по билетному партнеру. Таблица с данными у тебя есть (где видно, например, хорошие показатели у "Край билетов" и "Дом культуры"), но в итоговых пунктах ты об этом не написал. Стоит добавить пару слов о том, через каких партнеров приходят самые лояльные пользователи, чтобы картина была полной.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут актуально.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут также не исправлено. Подскажи, есть какие-то сложности?

# %% [markdown]
# ---
#
# **Задача 4.1.3.** Опираясь на выводы из задач выше, проверьте продуктовые гипотезы:
#
# - **Гипотеза 1.** Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
# - **Гипотеза 2.** В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#
# ---

# %%
import seaborn as sns

print("Проверка Гипотезы 1: Спорт vs Концерты")

# Считаем Retention для Спорта и Концертов
# Группируем данные по жанру (используем profiles, где уже есть is_two)
genre_stats = profiles.groupby('first_genre')['is_two'].mean().reset_index()

# Вытаскиваем конкретные значения
retention_sport = genre_stats.loc[genre_stats['first_genre'] == 'спорт', 'is_two'].values[0]
retention_concert = genre_stats.loc[genre_stats['first_genre'] == 'концерты', 'is_two'].values[0]

print(f"Доля возвратов (Спорт): {retention_sport:.2%}")
print(f"Доля возвратов (Концерты): {retention_concert:.2%}")
# Out:
# Проверка Гипотезы 1: Спорт vs Концерты
# Доля возвратов (Спорт): 56.40%
# Доля возвратов (Концерты): 62.31%

# %% [markdown]
# концерты работают лучше как точка входа для удержания аудитории

# %%
print("Проверка Гипотезы 2: Активность региона vs Возвращаемость")

# Готовим данные по регионам
# Нам нужно: Название региона, Кол-во пользователей (активность), Доля возвратов
region_stats = profiles.groupby('first_region').agg({
    'total_orders': 'count',
    'is_two': 'mean'
}).reset_index()
region_stats.rename(columns={'total_orders': 'user_count', 'is_two': 'retention_rate'}, inplace=True)

# Вычисляем корреляцию между размером региона и возвращаемостью
correlation = region_stats['user_count'].corr(region_stats['retention_rate'])
print(f"Корреляция между числом пользователей в регионе и долей возвратов: {correlation:.2f}")

# Визуализация (Scatter plot)
plt.figure(figsize=(10, 6))
sns.scatterplot(data=region_stats, x='user_count', y='retention_rate', size='user_count', sizes=(50, 500), alpha=0.7)

# Добавляем линию тренда
sns.regplot(data=region_stats, x='user_count', y='retention_rate', scatter=False, color='red', line_kws={'linestyle':'--'})

plt.title('Связь размера региона и доли повторных заказов')
plt.xlabel('Количество пользователей в регионе (Активность)')
plt.ylabel('Доля пользователей с 2+ заказами (Retention)')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Проверка Гипотезы 2: Активность региона vs Возвращаемость
# Корреляция между числом пользователей в регионе и долей возвратов: 0.12

# %% [markdown]
# Коэффициент корреляции равен 0.12. Это говорит об отсутствии значимой линейной зависимости. На графике видно, что линия тренда практически горизонтальна. Среди маленьких регионов есть как очень успешные (с возвратом выше 70%), так и аутсайдеры. Размер региона не гарантирует высокую лояльность

# %% [markdown]
# ### Результаты проверки гипотез
#
# 1.  **Гипотеза 1** (Пользователи спортивных мероприятий возвращаются чаще, чем посетители концертов).
#     * **Вердикт: Гипотеза опровергнута.**
#     * **Обоснование:** Анализ показал обратную ситуацию. Доля возвратов пользователей, совершивших первый заказ на **концерты**, составляет **62.3%**, в то время как у категории **«Спорт»** этот показатель ниже — **56.4%**. Концерты работают лучше как точка входа для удержания.
#
# 2.  **Гипотеза 2** (В более активных регионах доля повторных заказов выше).
#     * **Вердикт: Гипотеза не подтвердилась.**
#     * **Обоснование:** Коэффициент корреляции между количеством пользователей в регионе и долей возвратов составляет всего **0.12**. Это говорит об отсутствии значимой линейной связи. Размер региона не является гарантией высокой лояльности аудитории.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно интерпретировал данные при проверке обеих гипотез. В первом случае цифры четко показывают, что концерты удерживают аудиторию лучше спорта, и ты сделал правильный вывод.
#
# Вторая гипотеза проработана глубоко: ты не просто посмотрел на график, но и рассчитал коэффициент корреляции. Вывод о том, что размер региона не гарантирует лояльность, абсолютно верный и подтверждается почти горизонтальной линией тренда и низким значением 0.12.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> При формулировании выводов по гипотезам старайся начинать с четкого вердикта: «Гипотеза подтверждена» или «Гипотеза опровергнута». Это упрощает чтение отчета для заказчика. Например, в первом случае стоило написать: «Гипотеза не подтвердилась: концерты показывают более высокий процент возврата, чем спорт».

# %% [markdown]
# ---
#
# #### 4.2. Исследование поведения пользователей через показатели выручки и состава заказа
#
# Изучите количественные характеристики заказов пользователей, чтобы узнать среднюю выручку сервиса с заказа и количество билетов, которое пользователи обычно покупают.
#
# Эти метрики важны не только для оценки выручки, но и для оценки вовлечённости пользователей. Возможно, пользователи с более крупными и дорогими заказами более заинтересованы в сервисе и поэтому чаще возвращаются.
#
# ---
#
# **Задача 4.2.1.** Проследите связь между средней выручкой сервиса с заказа и повторными заказами.
#
# - Постройте сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):
#     - для пользователей, совершивших один заказ;
#     - для вернувшихся пользователей, совершивших 2 и более заказа.
# - Ответьте на вопросы:
#     - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#     - Есть ли различия между группами?
#
# Текст на сером фоне:
#
# **Рекомендация:**
#
# 1. Используйте одинаковые интервалы (`bins`) и прозрачность (`alpha`), чтобы визуально сопоставить распределения.
# 2. Задайте параметру `density` значение `True`, чтобы сравнивать форму распределений, даже если число пользователей в группах отличается.
#
# ---

# %%
one_order_users = profiles[profiles['total_orders'] == 1]
loyal_users = profiles[profiles['total_orders'] >= 2]

plt.figure(figsize=(12, 6))

sns.histplot(one_order_users['avg_revenue'], color='grey', stat='density', 
             bins=50, alpha=0.5, label='1 заказ (Разовые)', kde=True)

sns.histplot(loyal_users['avg_revenue'], color='green', stat='density', 
             bins=50, alpha=0.5, label='2+ заказа (Лояльные)', kde=True)

plt.xlim(0, 3000)

plt.title('Распределение средней выручки с заказа (Rub): Разовые vs Лояльные')
plt.xlabel('Средняя выручка (руб.)')
plt.ylabel('Плотность распределения (Density)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# Выводим средние значения текстом для точности
print(f"Средний чек разовых клиентов: {one_order_users['avg_revenue'].mean():.2f} руб.")
print(f"Средний чек лояльных клиентов: {loyal_users['avg_revenue'].mean():.2f} руб.")
# Out:
# Средний чек разовых клиентов: 540.32 руб.
# Средний чек лояльных клиентов: 541.56 руб.

# %% [markdown]
# ### Вывод по распределению выручки
#
# 1.  **Диапазоны концентрации:**
#     * **Разовые пользователи (1 заказ):** Имеют ярко выраженный пик в зоне низкой стоимости (от 0 до 300 рублей). Многие приходят за дешевыми или акционными билетами.
#     * **Лояльные пользователи (2+ заказа):** Их траты распределены более кучно ("колоколом") с основной концентрацией в диапазоне **400–800 рублей**.
#
# 2.  **Различия между группами:**
#     * Средний чек практически идентичен (~540 руб.), но поведение разное.
#     * **Разовые клиенты** демонстрируют более высокий разброс (дисперсию): они чаще других покупают самые дешевые билеты, но при этом их "хвост" дорогих покупок (1500+ руб.) даже чуть более выражен. То есть эта группа ведет себя менее предсказуемо.
#     * **Лояльные клиенты** более стабильны. Они реже берут экстремально дешевые или дорогие билеты, предпочитая уверенный "средний" ценовой сегмент.- Разовые пользователи (1 заказ): Имеют ярко выраженный пик в зоне низкой стоимости (от 0 до 300 рублей). Это говорит о том, что многие пользователи приходят ради дешевого билета (возможно, по акции) и больше не возвращаются.
#
# - Лояльные пользователи (2+ заказа): Их траты распределены более нормально (колоколообразно). Основная концентрация находится в диапазоне 400–800 рублей.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты сделал очень качественный и глубокий вывод. Заметить, что при практически равном среднем чеке (около 540 рублей) структура трат кардинально отличается - это сильный аналитический инсайт, который часто упускают, глядя только на средние значения.
#
# График построен информативно: использование линий плотности распределения поверх гистограммы помогает легче считывать форму данных. Ты верно определил ключевые диапазоны: смещение разовых пользователей в зону «до 300 рублей» и концентрацию лояльной аудитории в «среднем» сегменте 400–800 рублей.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В выводе ты отметил, что лояльные клиенты «не склонны к экстремально дорогим покупкам». Если посмотреть на правые «хвосты» графиков (область 1500–2500 рублей), видно, что они затухают примерно одинаково или даже у разовых пользователей хвост чуть более выражен. То есть дорогие покупки редки для обеих групп. Правильнее было бы сказать, что у разовых пользователей просто выше разброс (дисперсия): они чаще берут и самое дешевое, и иногда дорогое, тогда как лояльные пользователи ведут себя более предсказуемо и стабильно, выбирая средний ценовой сегмент.

# %% [markdown]
# ---
#
# **Задача 4.2.2.** Сравните распределение по средней выручке с заказа в двух группах пользователей:
#
# - совершившие 2–4 заказа;
# - совершившие 5 и более заказов.
#
# Ответьте на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
#
# ---

# %%
mid_loyal = profiles[(profiles['total_orders'] >= 2) & (profiles['total_orders'] <= 4)]
super_loyal = profiles[profiles['total_orders'] >= 5]

plt.figure(figsize=(12, 6))

sns.histplot(mid_loyal['avg_revenue'], color='blue', stat='density', 
             bins=50, alpha=0.5, label='2-4 заказа (Средняя лояльность)', kde=True)

sns.histplot(super_loyal['avg_revenue'], color='orange', stat='density', 
             bins=50, alpha=0.5, label='5+ заказов (Высокая лояльность)', kde=True)

plt.xlim(0, 3000)
plt.title('Сравнение средней выручки: 2-4 заказа vs 5+ заказов')
plt.xlabel('Средняя выручка с заказа (руб.)')
plt.ylabel('Плотность (Density)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# Расчет средних значений для выводов
mean_mid = mid_loyal['avg_revenue'].mean()
mean_super = super_loyal['avg_revenue'].mean()

print(f"Средний чек (2-4 заказа): {mean_mid:.2f} руб.")
print(f"Средний чек (5+ заказов): {mean_super:.2f} руб.")
# Out:
# Средний чек (2-4 заказа): 548.52 руб.
# Средний чек (5+ заказов): 533.76 руб.

# %% [markdown]
# В среднем значении разница минимальна: 548.52 руб. (2-4 заказа) против 533.76 руб. (5+ заказов)

# %% [markdown]
# Интересный факт: самые лояльные пользователи в среднем тратят даже немного меньше, чем пользователи средней лояльности. Это опровергает миф о том, что постоянный клиент всегда платит больше за один визит.

# %% [markdown]
# ### Вывод по сравнению групп лояльности
#
# 1.  **Различия по средней выручке:**
#     * Средние значения чека отличаются незначительно: **548.52 руб.** у группы "2-4 заказа" против **533.76 руб.** у группы "5+ заказов".
#     * Самые лояльные клиенты в среднем тратят даже чуть меньше, что опровергает гипотезу о росте среднего чека с ростом лояльности.
#
# 2.  **Различия в поведении (распределении):**
#     * **Группа «2-4 заказа»:** Демонстрирует более хаотичное поведение. У них не только высокая доля дешевых покупок (до 300 руб.), но и более "тяжелый" правый хвост графика (в диапазоне 1000–1500 рублей). Это значит, что такие пользователи еще не определились с комфортной ценой и экспериментируют, покупая как очень дешевые, так и дорогие билеты.
#     * **Группа «5+ заказов»:** Показывает высокую стабильность и предсказуемость. Их траты сконцентрированы в узком диапазоне **450–650 рублей**. Эта аудитория нашла свою "золотую середину" и редко выходит за её пределы, избегая рисков (слишком дешево) и переплат (слишком дорого).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты отлично справился с задачей, не ограничившись сравнением только средних значений. Вывод о том, что самые лояльные пользователи (5+ заказов) ведут себя стабильнее и концентрируются в определенном ценовом диапазоне - это сильный инсайт.
#
# Очень верно подмечено, что постоянный клиент не обязательно платит больше за один раз, он платит регулярнее. График с линиями плотности наглядно подтверждает твои слова про «золотую середину» для сегмента 5+.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В описании группы 2-4 заказа ты указал на высокую долю дешевых покупок. Это верно, но стоит также отметить, что их график более «размазан» и в правую сторону (в диапазоне 1000–1500 рублей синяя линия часто выше желтой). То есть эта группа не просто покупает дешевле, она действует более хаотично: берет и самое дешевое, и более дорогое, в то время как лояльные пользователи уже определились с комфортной ценой и редко из нее выходят.

# %% [markdown]
# ---
#
# **Задача 4.2.3.** Проанализируйте влияние среднего количества билетов в заказе на вероятность повторной покупки.
#
# - Изучите распределение пользователей по среднему количеству билетов в заказе (`avg_tickets_count`) и опишите основные наблюдения.
# - Разделите пользователей на несколько сегментов по среднему количеству билетов в заказе:
#     - от 1 до 2 билетов;
#     - от 2 до 3 билетов;
#     - от 3 до 5 билетов;
#     - от 5 и более билетов.
# - Для каждого сегмента подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы.
# - Ответьте на вопросы:
#     - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#
# ---

# %%
print("Общая статистика по среднему количеству билетов")
print(profiles['avg_tickets'].describe())

# Гистограмма распределения
plt.figure(figsize=(10, 5))
sns.countplot(x=profiles['avg_tickets'].round().astype(int), color='teal')
plt.title('Распределение пользователей по количеству билетов (округлено до целого)')
plt.xlabel('Среднее кол-во билетов (округлено)')
plt.ylabel('Количество пользователей')
plt.grid(True, alpha=0.3)
plt.show()

# Сегментация
def get_ticket_segment(x):
    if 1 <= x < 2:
        return '1. Одиночки (1 билет)'
    elif 2 <= x < 3:
        return '2. Пары (2 билета)'
    elif 3 <= x < 5:
        return '3. Компании (3-4 билета)'
    elif x >= 5:
        return '4. Группы (5+ билетов)'
    else:
        return 'Other'

profiles['ticket_segment'] = profiles['avg_tickets'].apply(get_ticket_segment)

# Группировка и расчет метрик
ticket_stats = profiles.groupby('ticket_segment').agg({
    'total_orders': 'count',     # Размер сегмента
    'is_two': 'mean'             # Retention rate
}).reset_index()

ticket_stats.rename(columns={'total_orders': 'user_count', 'is_two': 'retention_rate'}, inplace=True)
ticket_stats['share_of_users'] = (ticket_stats['user_count'] / len(profiles)) * 100

print("\nСегментация по билетам и возврат")
print(ticket_stats)

# Визуализация
plt.figure(figsize=(10, 6))

avg_ret = profiles['is_two'].mean()
colors = ['green' if x > avg_ret else 'gray' for x in ticket_stats['retention_rate']]

sns.barplot(data=ticket_stats, x='ticket_segment', y='retention_rate', palette=colors)
plt.axhline(y=avg_ret, color='red', linestyle='--', label=f'Среднее ({avg_ret:.2f})')

plt.title('Влияние размера компании (кол-ва билетов) на возврат')
plt.xlabel('Сегмент')
plt.ylabel('Доля возвратов (2+ заказа)')
plt.xticks(rotation=15)
plt.legend()
plt.grid(axis='y', alpha=0.3)
plt.show()
# Out:
# Общая статистика по среднему количеству билетов
# count    21726.000000
# mean         2.713767
# std          0.860383
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.000000
# max          5.000000
# Name: avg_tickets, dtype: float64
# Сегментация по билетам и возврат
#              ticket_segment  user_count  retention_rate  share_of_users
# 0     1. Одиночки (1 билет)        2431        0.513369       11.189358
# 1        2. Пары (2 билета)        9731        0.742164       44.789653
# 2  3. Компании (3-4 билета)        9097        0.543476       41.871490
# 3    4. Группы (5+ билетов)         467        0.130621        2.149498
# C:\Users\alexa\AppData\Local\Temp\ipykernel_47580\423090542.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# Пользователи распределены неравномерно и сильно сконцентрированы. Абсолютное большинство (суммарно около 86.7%) покупает от 2 до 5 билетов. Самый массовый сегмент — "От 2 до 3 билетов" (44.8%). Это классический сценарий "поход вдвоем" (пары). Одиночные посетители (1-2 билета) составляют лишь 11.2%.

# %% [markdown]
# ### Вывод по количеству билетов
#
# 1.  **Общее распределение:**
#     * Среднее количество билетов в заказе составляет **2.7**, медиана — **2.75**.
#     * Распределение не является нормальным, оно дискретно и имеет явные пики на целых числах (2, 3, 4).
#     * Абсолютное большинство пользователей покупает от 2 до 4 билетов.
#
# 2.  **Анализ сегментов:**
#     * **«Пары» (2 билета):** Самый массовый сегмент (44.8% пользователей). Поскольку мы работаем с дискретными величинами, в интервал "от 2 до 3" попадают именно те, кто берет **ровно 2 билета** (или в среднем 2.x, но ближе к 2). Этот сегмент показывает феноменальную лояльность — **74.2%** возвратов.
#     * **«Одиночки» (1 билет):** Составляют 11.2% аудитории. Их лояльность ниже средней (51%). Ходить на мероприятия одному — менее устойчивая привычка.
#     * **«Компании» (3-4 билета):** Крупный сегмент (41.9%), но возврат уже ниже среднего (54%). Организовать компанию сложнее, чем пару.
#     * **«Группы» (5+ билетов):** Малочисленный сегмент (2%) с крайне низким возвратом (13%). Это разовые организаторы, а не постоянные клиенты.
#
# **Итог:** "Парное посещение" — основной драйвер повторных покупок.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты отлично интерпретировал данные таблицы. Все цифры в выводах (доли сегментов и показатели возврата) указаны верно.
#
# Особенно сильной частью является качественная интерпретация цифр: ты не просто констатировал факты, но и выдвинул логичные гипотезы о природе этих сегментов. Идея о том, что сегмент "от 2 до 3" - это пары ("поход вдвоем"), и именно они являются самой лояльной "золотой аудиторией", звучит очень убедительно. Также верно подмечено про организаторов групповых мероприятий в сегменте "5+", для которых сервис является разовым инструментом.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Стоит немного уточнить понимание интервалов при работе с дискретными величинами (билетами). Технически диапазон "от 2 до 3" (если мы говорим о стандартном разбиении) чаще всего включает 2, но не включает 3. То есть этот сегмент фактически состоит из тех, кто берет в среднем ровно 2 билета. А сегмент "от 3 до 5" - это 3 и 4 билета. В твоем выводе это подразумевается, но явный акцент на том, что почти половина аудитории покупает строго 2 билета, сделал бы картину еще четче.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не выполнена первая часть задания `Изучите распределение пользователей по среднему количеству билетов в заказе (avg_tickets_count) и опишите основные наблюдения` - она предполагает анализ `avg_tickets_count` без учёта сегментации.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Для анализа распределения дискретных признаков нужен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать `sns.countplot` или `.plot(kind='bar')`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# #### 4.3. Исследование временных характеристик первого заказа и их влияния на повторные покупки
#
# Изучите временные параметры, связанные с первым заказом пользователей:
#
# - день недели первой покупки;
# - время с момента первой покупки — лайфтайм;
# - средний интервал между покупками пользователей с повторными заказами.
#
# ---
#
# **Задача 4.3.1.** Проанализируйте, как день недели, в которой была совершена первая покупка, влияет на поведение пользователей.
#
# - По данным даты первого заказа выделите день недели.
# - Для каждого дня недели подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы. Результаты визуализируйте.
# - Ответьте на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#
# ---

# %%
# Извлекаем день недели из даты первого заказа
profiles['first_day_name'] = profiles['first_order_dt'].dt.day_name()

# Создаем порядок дней недели для правильной сортировки на графике
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Группируем и считаем метрики
day_stats = profiles.groupby('first_day_name').agg({
    'total_orders': 'count',
    'is_two': 'mean'
}).reindex(days_order).reset_index() # reindex выстроит дни по порядку

day_stats.rename(columns={'total_orders': 'user_count', 'is_two': 'retention_rate', 'first_day_name': 'day_of_week'}, inplace=True)

print("Статистика по дням недели")
print(day_stats)


plt.figure(figsize=(10, 6))

# Линия среднего возврата
avg_ret = profiles['is_two'].mean()

colors = ['green' if x > avg_ret else 'gray' for x in day_stats['retention_rate']]

plt.bar(day_stats['day_of_week'], day_stats['retention_rate'], color=colors, alpha=0.7)
plt.axhline(y=avg_ret, color='red', linestyle='--', label=f'Среднее ({avg_ret:.2f})')

plt.title('Влияние дня недели первой покупки на возврат')
plt.xlabel('День недели')
plt.ylabel('Доля возвратов (Retention Rate)')
plt.ylim(0, 0.8)
plt.legend()
plt.grid(axis='y', alpha=0.3)
plt.show()
# Out:
# Статистика по дням недели
#   day_of_week  user_count  retention_rate
# 0      Monday        2930        0.633788
# 1     Tuesday        3169        0.623856
# 2   Wednesday        3055        0.627496
# 3    Thursday        3098        0.597159
# 4      Friday        3237        0.603027
# 5    Saturday        3441        0.645743
# 6      Sunday        2796        0.608011

# %% [markdown]
# ### Вывод по дням недели
#
# 1.  **Влияние дня недели:**
#     День первой покупки существенно влияет на вероятность того, станет ли пользователь постоянным клиентом.
#
# 2.  **Детальный анализ:**
#     * **Суббота — абсолютный лидер.** Это «точка силы» сервиса: максимум новых пользователей (3441) и самая высокая лояльность (**64.6%**). Люди, планирующие досуг в субботу, — самая качественная аудитория.
#     * **Пятница — парадокс.** Занимает уверенное **второе место** по количеству новичков (3237), но показывает один из самых **низких** процентов возврата (60.3%).
#         * *Инсайт:* В пятницу приходит много «спонтанных» пользователей (вероятно, ищут, куда сходить вечером), но этот визит часто остается единственным.
#     * **Четверг — аутсайдер.** Низкие показатели как по объему аудитории, так и по удержанию (минимум в выборке — 59.7%).
#     * **Начало недели (Пн-Ср):** Стабильно высокие показатели возврата (62-63%), хотя объем аудитории ниже выходных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно определил ключевые тренды в таблице. Суббота действительно является абсолютным лидером как по привлечению новой аудитории, так и по ее удержанию. Также правильно отмечен спад показателя возвращаемости (retention rate) в четверг и пятницу. Вывод о том, что день недели влияет на поведение пользователя, логичен и подтверждается цифрами.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Стоит уточнить комментарий про пятницу. Ты пишешь, что она "проседает" в одном ряду с четвергом. Это верно для процента возврата, но не для количества пользователей. По объему аудитории пятница занимает уверенное второе место (сразу после субботы). Получается важный инсайт: в пятницу приходит много новичков, но их лояльность ниже средней. Это отличается от четверга, где низкие и объем, и качество.

# %% [markdown]
# ---
#
# **Задача 4.3.2.** Изучите, как средний интервал между заказами влияет на удержание клиентов.
#
# - Рассчитайте среднее время между заказами для двух групп пользователей:
#     - совершившие 2–4 заказа;
#     - совершившие 5 и более заказов.
# - Исследуйте, как средний интервал между заказами влияет на вероятность повторного заказа, и сделайте выводы.
#
# ---

# %%
group_mid = profiles[(profiles['total_orders'] >= 2) & (profiles['total_orders'] <= 4)]
group_high = profiles[profiles['total_orders'] >= 5]

mean_interval_mid = group_mid['avg_inter_order_time'].mean()
mean_interval_high = group_high['avg_inter_order_time'].mean()

print(f"Средний интервал (2-4 заказа): {mean_interval_mid:.2f} дней")
print(f"Средний интервал (5+ заказов): {mean_interval_high:.2f} дней")

# Визуализация (Boxplot + Гистограмма)
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Boxplot
plot_data = pd.concat([
    group_mid[['avg_inter_order_time']].assign(group='2-4 заказа'),
    group_high[['avg_inter_order_time']].assign(group='5+ заказов')
])
sns.boxplot(data=plot_data, x='group', y='avg_inter_order_time', palette=['blue', 'orange'], ax=axes[0])
axes[0].set_title('Разброс интервалов (Boxplot)')
axes[0].set_ylim(0, 100)
axes[0].set_ylabel('Средний интервал (дней)')

# Нормированная гистограмма
sns.histplot(group_mid['avg_inter_order_time'], color='blue', stat='density', 
             bins=50, alpha=0.5, label='2-4 заказа', kde=True, ax=axes[1])
sns.histplot(group_high['avg_inter_order_time'], color='orange', stat='density', 
             bins=50, alpha=0.5, label='5+ заказов', kde=True, ax=axes[1])

axes[1].set_title('Плотность распределения интервалов')
axes[1].set_xlabel('Дни между покупками')
axes[1].set_xlim(0, 60)
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# Средний интервал (2-4 заказа): 21.43 дней
# Средний интервал (5+ заказов): 9.60 дней
# C:\Users\alexa\AppData\Local\Temp\ipykernel_47580\2133693869.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=plot_data, x='group', y='avg_inter_order_time', palette=['blue', 'orange'], ax=axes[0])

# %% [markdown]
# ### Вывод по интервалам между покупками
#
# 1.  **Среднее vs Медиана (Влияние выбросов):**
#     * **Средний интервал** в группе «2-4 заказа» (**21.5 дней**) более чем в 2 раза превышает показатель группы «5+ заказов» (**9.7 дней**).
#     * Однако **медианные значения** (центральные линии в "ящиках") различаются не так сильно: около **10-12 дней** у "середнячков" против **~8 дней** у лояльных.
#     * Это говорит о том, что типичный пользователь из первой группы возвращается ненамного медленнее. Высокое среднее значение обусловлено "длинным хвостом" пользователей, которые возвращаются спустя 2-3 месяца (выбросы на графике).
#
# 2.  **Фактор стабильности (Гистограмма):**
#     * Главное отличие супер-лояльных клиентов — **стабильность**. На гистограмме их распределение имеет высокий и узкий пик. Они предсказуемы: сходили раз, через неделю-две пришли снова.
#     * Группа «2-4 заказа» имеет «размазанное» распределение. Их возвращение хаотично: это может быть спонтанная покупка через 3 дня или запланированный поход через 2 месяца.
#
# 3.  **Влияние на вероятность повтора:**
#     * Нормированные гистограммы показывают: если интервал между покупками составляет **до 14 дней**, вероятность того, что пользователь закрепится в сегменте «супер-лояльных», максимальна.
#     * С увеличением интервала (> 30 дней) плотность распределения лояльной группы стремится к нулю, тогда как "середнячки" всё еще активны. Длительные паузы снижают шанс формирования привычки.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты сделал очень сильный продуктовый вывод. Идея про «критическое окно» в 10–14 дней - это отличный инсайт. Он действительно считывается с графика: у группы «5+ заказов» (желтый ящик) основной массив значений (75%) укладывается как раз в этот промежуток. Это готовая рекомендация для настройки рассылок или пуш-уведомлений.
#
# Расчеты средних значений верны, и сравнение (21 день против 9 дней) корректно обосновывает тезис о том, что лояльные клиенты покупают в два раза чаще. Визуализация через boxplot (ящик с усами) здесь подходит идеально, так как показывает разброс.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Стоит обратить внимание на разницу между средним и медианой. У группы «2–4 заказа» (синий ящик) очень много выбросов сверху - длинная линия, уходящая к 100 дням. Именно эти «пропавшие» пользователи тянут среднее значение вверх (до 21 дня). Если посмотреть на медиану (горизонтальная черта внутри синего ящика), она находится в районе 10–12 дней, что довольно близко к медиане лояльной группы (около 8 дней).
#
# То есть типичный пользователь из первой группы возвращается не в два раза медленнее, а лишь немного медленнее. Главное отличие лояльных клиентов — не столько в скорости, сколько в стабильности: у них очень кучный график (узкий ящик), они почти всегда возвращаются в предсказуемый срок, тогда как новички могут вернуться и через неделю, и через три месяца. Это уточнение сделает портрет пользователя еще точнее.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не выполнена вторая часть задания `Исследуйте, как средний интервал между заказами влияет на вероятность повторного заказа, и сделайте выводы` - тут стоит сравнить распределение `avg_inter_order_time` между группами с помощью нормированной гистограммы.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут не исправлено.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# #### 4.4. Корреляционный анализ количества покупок и признаков пользователя
#
# Изучите, какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок. Для этого используйте универсальный коэффициент корреляции `phi_k`, который позволяет анализировать как числовые, так и категориальные признаки.
#
# ---
#
# **Задача 4.4.1:** Проведите корреляционный анализ:
# - Рассчитайте коэффициент корреляции `phi_k` между признаками профиля пользователя и числом заказов (`total_orders`). При необходимости используйте параметр `interval_cols` для определения интервальных данных.
# - Проанализируйте полученные результаты. Если полученные значения будут близки к нулю, проверьте разброс данных в `total_orders`. Такое возможно, когда в данных преобладает одно значение: в таком случае корреляционный анализ может показать отсутствие связей. Чтобы этого избежать, выделите сегменты пользователей по полю `total_orders`, а затем повторите корреляционный анализ. Выделите такие сегменты:
#     - 1 заказ;
#     - от 2 до 4 заказов;
#     - от 5 и выше.
# - Визуализируйте результат корреляции с помощью тепловой карты.
# - Ответьте на вопрос: какие признаки наиболее связаны с количеством заказов?
#
# ---

# %%
# Отбираем признаки для анализа
# Нам интересно, что влияет на 'total_orders' (и 'is_two')
cols_for_corr = [
    'total_orders',
    'avg_revenue',
    'avg_tickets',
    'avg_inter_order_time',
    'first_device',
    'first_partner',
    'first_genre',
    'first_region'
]
df_corr = profiles[cols_for_corr].copy()

# Расчет матрицы корреляций
# interval_cols указывает, какие столбцы являются непрерывными числами
interval_cols = ['total_orders', 'avg_revenue', 'avg_tickets', 'avg_inter_order_time']

phik_overview = df_corr.phik_matrix(interval_cols=interval_cols)

# Визуализация тепловой карты
print("Матрица корреляций (Phi_k)")

plt.figure(figsize=(12, 10))
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map="Greens",
    title="Корреляция признаков профиля (Phi_k)",
    fontsize_factor=1.2,
    figsize=(10, 8)
)
plt.tight_layout()
plt.show()

# Анализ связи конкретно с total_orders
print("Топ признаков, влияющих на количество заказов (total_orders):")
print(phik_overview['total_orders'].sort_values(ascending=False)[1:])
# Out:
# Матрица корреляций (Phi_k)
# Топ признаков, влияющих на количество заказов (total_orders):
# first_region            0.126459
# first_partner           0.109003
# avg_tickets             0.066528
# avg_inter_order_time    0.000000
# avg_revenue             0.000000
# first_device            0.000000
# first_genre             0.000000
# Name: total_orders, dtype: float64

# %%
# Создаем сегменты лояльности
def get_loyalty_level(x):
    if x == 1:
        return '1. Один заказ'
    elif 2 <= x <= 4:
        return '2. От 2 до 4 заказов'
    else:
        return '3. От 5 и выше'

profiles['loyalty_level'] = profiles['total_orders'].apply(get_loyalty_level)

# Обновляем список колонок
# Вместо total_orders берем loyalty_level
cols_for_seg_corr = [
    'loyalty_level',
    'avg_revenue',
    'avg_tickets',
    'avg_inter_order_time',
    'first_device',
    'first_partner',
    'first_genre',
    'first_region'
]

df_seg_corr = profiles[cols_for_seg_corr].copy()

# Считаем Phi_k
interval_cols = ['avg_revenue', 'avg_tickets', 'avg_inter_order_time']
phik_segment = df_seg_corr.phik_matrix(interval_cols=interval_cols)

# Визуализация
print("Матрица корреляций по СЕГМЕНТАМ (Phi_k)")

plt.figure(figsize=(12, 10))
plot_correlation_matrix(
    phik_segment.values,
    x_labels=phik_segment.columns,
    y_labels=phik_segment.index,
    vmin=0, vmax=1, color_map="Blues",
    title="Корреляция с уровнем лояльности (Phi_k)",
    fontsize_factor=1.2,
    figsize=(10, 8)
)
plt.tight_layout()
plt.show()


print("Топ признаков, влияющих на Уровень Лояльности:")
print(phik_segment['loyalty_level'].sort_values(ascending=False)[1:])
# Out:
# Матрица корреляций по СЕГМЕНТАМ (Phi_k)
# Топ признаков, влияющих на Уровень Лояльности:
# avg_tickets             0.653303
# avg_inter_order_time    0.394614
# avg_revenue             0.336773
# first_region            0.126570
# first_partner           0.093588
# first_genre             0.051976
# first_device            0.027964
# Name: loyalty_level, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> По этому заданию нет выводов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Вывод по корреляционному анализу
#
# 1.  **Эффект сегментации:**
#     * Анализ линейной корреляции с «сырым» количеством заказов не дал результатов (коэффициенты около 0 из-за дисбаланса данных).
#     * Однако анализ связи с **уровнем лояльности** (сегменты: 1 заказ / 2-4 заказа / 5+) выявил сильные зависимости.
#
# 2.  **Ключевые драйверы лояльности:**
#     * **Среднее количество билетов (`avg_tickets`):** Самая сильная связь (**0.65**). Это подтверждает вывод из раздела 4.2.3: «парные» покупки (2-3 билета) — самый сильный индикатор того, что клиент вернется.
#     * **Интервал между покупками (`avg_inter_order_time`):** Сильная связь (**0.47**). Чем меньше времени проходит между заказами, тем выше вероятность формирования привычки.
#     * **Средний чек (`avg_revenue`):** Средняя связь (**0.34**). Влияние есть, но оно слабее, чем у поведенческих факторов (частоты и объема заказа).
#
# 3.  **Слабые факторы:**
#     * Характеристики **первого заказа** (регион, жанр, партнер, устройство) имеют низкую корреляцию (от 0.03 до 0.13).
#     * **Вывод:** Для прогнозирования возврата важнее анализировать **поведение** пользователя (как часто и сколько билетов берет), а не демографию или канал привлечения.

# %% [markdown]
# ### 5. Общий вывод и рекомендации
#
# В конце проекта напишите общий вывод и рекомендации: расскажите заказчику, на что нужно обратить внимание. В выводах кратко укажите:
#
# - **Информацию о данных**, с которыми вы работали, и то, как они были подготовлены: например, расскажите о фильтрации данных, переводе тенге в рубли, фильтрации выбросов.
# - **Основные результаты анализа.** Например, укажите:
#     - Сколько пользователей в выборке? Как распределены пользователи по числу заказов? Какие ещё статистические показатели вы подсчитали важным во время изучения данных?
#     - Какие признаки первого заказа связаны с возвратом пользователей?
#     - Как связаны средняя выручка и количество билетов в заказе с вероятностью повторных покупок?
#     - Какие временные характеристики влияют на удержание (день недели, интервалы между покупками)?
#     - Какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок согласно результатам корреляционного анализа?
# - Дополните выводы информацией, которая покажется вам важной и интересной. Следите за общим объёмом выводов — они должны быть компактными и ёмкими.
#
# В конце предложите заказчику рекомендации о том, как именно действовать в его ситуации. Например, укажите, на какие сегменты пользователей стоит обратить внимание в первую очередь, а какие нуждаются в дополнительных маркетинговых усилиях.

# %% [markdown]
# ## Общий вывод и рекомендации
#
# В ходе исследования был проведен анализ данных о покупках пользователей сервиса Яндекс Афиша. Были изучены профили 21 920 пользователей.
# **Подготовка данных:** Произведена конвертация валют (тенге приведены к рублю), данные очищены от аномальных выбросов (удалено ~0.9% заказов с экстремально высокой стоимостью).
#
# ### 1. Портрет пользователя и ключевые метрики
# * **Удержание:** 61.8% пользователей совершили повторную покупку (2 и более заказа). 29% пользователей являются «супер-лояльными» (5+ заказов).
# * **Средний чек:** Около 540 рублей. Интересно, что средний чек не растет с лояльностью — постоянные клиенты тратят столько же, сколько и новички, но делают это чаще и стабильнее.
#
# ### 2. Факторы, влияющие на возвращаемость (Retention)
# На основе анализа выявлены ключевые индикаторы, предсказывающие возврат клиента:
#
# * **Компанейские покупки (Самый сильный фактор):**
#     * Пользователи, покупающие **2-3 билета** в заказе, имеют аномально высокий возврат (**74%**).
#     * Одиночки (1 билет) и большие группы (5+ билетов) возвращаются значительно реже (51% и 13% соответственно).
# * **Скорость возврата (Привычка):**
#     * У самых лояльных клиентов (5+ заказов) средний интервал между покупками составляет **9-10 дней**.
#     * Если интервал увеличивается до 3 недель, пользователь чаще остается в сегменте «середнячков» (2-4 заказа).
# * **День первого заказа:**
#     * Пользователи, совершившие первую покупку в **субботу**, показывают максимальную лояльность (64.6%). Четверг и пятница — дни с наименьшим возвратом.
# * **Точка входа (Каналы и Партнеры):**
#     * **Жанры:** Театры и Выставки удерживают аудиторию лучше (64%), чем Концерты (62%) и Спорт (56%).
#     * **Устройства:** Пользователи Desktop возвращаются чаще, чем мобильные пользователи.
#     * **Партнеры:** Лидер по объему — оператор «Билеты без проблем» (24% аудитории). Также значимые доли занимают «Мой билет» и «Лови билет!».
#
# ### 3. Проверка гипотез
# 1.  **Гипотеза «Спорт лучше Концертов»:** Опровергнута. Концерты показывают более высокий Retention (62% против 56% у спорта).
# 2.  **Гипотеза «Крупные регионы лояльнее»:** Опровергнута. Связи между размером региона и долей повторных покупок не обнаружено (корреляция 0.12).
#
# ### 4. Рекомендации для бизнеса
# 1.  **Фокус на «парных» продажах:**
#     * Разработать маркетинговые предложения для покупки **2-3 билетов** (например, «скидка на второй билет» или подборки «куда пойти вдвоем»). Это ядро нашей лояльной аудитории.
# 2.  **Работа с окном внимания (14 дней):**
#     * Настроить CRM-рассылки и пуш-уведомления так, чтобы стимулировать вторую покупку в течение **10-14 дней** после первой. Это критический срок для формирования привычки.
# 3.  **Оптимизация рекламного трафика:**
#     * Увеличить бюджеты на привлечение пользователей в **субботу** (самая качественная аудитория).
#     * Пересмотреть стратегии привлечения на спортивные мероприятия и в будние дни (четверг-пятница), так как эти пользователи хуже удерживаются.
# 4.  **Ценообразование:**
#     * Лояльная аудитория концентрируется в чеке **450–650 рублей**. Стоит поддерживать ассортимент событий в этой ценовой категории, так как она наиболее востребована у постоянных клиентов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Это отличный итоговый вывод. Он выглядит как готовый отчет для руководителя: структурированный, с четкими цифрами и, самое главное, с прикладными рекомендациями. Ты прошел по всем пунктам задания (портрет, признаки первого заказа, временные характеристики, гипотезы).
#
# Отчет разбит на логические блоки: данные -> портрет -> факторы -> гипотезы -> рекомендации. Это легко читать.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В задании (первый пункт на скриншоте) просили указать информацию о «переводе тенге в рубли». В твоем введении сказано только про очистку от выбросов. Хотя все суммы у тебя уже в рублях, формально стоит добавить одну фразу: «Произведена конвертация валют и фильтрация аномалий».
#
# В ходе анализа (в предыдущих шагах) ты строил таблицу по билетным операторам («Билеты без проблем» и т.д.), и там были явные лидеры. В итоговый вывод эта информация не попала.

# %% [markdown]
# ### 6. Финализация проекта и публикация в Git
#
# Когда вы закончите анализировать данные, оформите проект, а затем опубликуйте его.
#
# Выполните следующие действия:
#
# 1. Создайте файл `.gitignore`. Добавьте в него все временные и чувствительные файлы, которые не должны попасть в репозиторий.
# 2. Сформируйте файл `requirements.txt`. Зафиксируйте все библиотеки, которые вы использовали в проекте.
# 3. Вынести все чувствительные данные (параметры подключения к базе) в `.env`файл.
# 4. Проверьте, что проект запускается и воспроизводим.
# 5. Загрузите проект в публичный репозиторий — например, на GitHub. Убедитесь, что все нужные файлы находятся в репозитории, исключая те, что в `.gitignore`. Ссылка на репозиторий понадобится для отправки проекта на проверку. Вставьте её в шаблон проекта в тетрадке Jupyter Notebook перед отправкой проекта на ревью.

# %% [markdown]
# **Вставьте ссылку на проект в этой ячейке тетрадки перед отправкой проекта на ревью.**

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Евгений, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)
